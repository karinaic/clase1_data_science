# %%
import pandas as pd

# %%
path = 'detallado_cajarural_2022.xlsx'

# %%
pd.read_excel(path)
# Out:
#      Response ID                          Email  Invite Custom Field 1  \
# 0              2     pablofernandez@crsoria.com                    NaN
# 1              3    carlosfernandez@crsoria.com                    NaN
# 2              4    victordelapinta@crsoria.com                    NaN
# 3              5  arantxacastellano@crsoria.com                    NaN
# 4              6       javiergarcia@crsoria.com                    NaN
# ..           ...                            ...                    ...
# 112          120   davidcarraminana@crsoria.com                    NaN
# 113          121       sarasanguesa@crsoria.com                    NaN
# 114          122         anatamames@crsoria.com                    NaN
# 115          123      cristinaperez@crsoria.com                    NaN
# 116          124       amandafalcon@crsoria.com                    NaN
#
#      Invite Custom Field 2  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# ...
