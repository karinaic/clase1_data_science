# %%
import pandas as pd

# %%
df = pd.read_excel("informacion.xlsx")

df
# Out:
#     Reviewid                                          Nombre  \
# 0        NaN                             Biblioteca Nacional
# 1        NaN                                 Casa de América
# 2        NaN                             Palacio de Cibeles.
# 3        NaN                                 Museo del Prado
# 4        NaN                       Museo Thyssen-Bornemisza.
# 5        NaN                           Real Jardín Botánico.
# 6        NaN                              Museo Reina Sofía.
# 7        NaN                                     Plaza Mayor
# 8        NaN                          Mercado de San Miguel.
# 9        NaN                          Centro Sefarad Israel.
# 10       NaN                           Jardines de Sabatini.
# 11       NaN             Museo de la Catedral de la Almudena
# 12       NaN                                   Palacio Real.
# 13       NaN                                    Teatro Real.
# ...
